# %%
import matplotlib.pyplot as plt
import numpy as np 
import pandas as pd 
import random
from sklearn import datasets, linear_model
from sklearn.model_selection import train_test_split

# %%
df= pd.read_csv('D:/cars-data.csv')
df
# Out:
#       Id   MPG  Cylinders  Edispl  Horsepower  Weight  Accelerate  Year
# 0      1  18.0          8   307.0       130.0    3504        12.0  1970
# 1      2  15.0          8   350.0       165.0    3693        11.5  1970
# 2      3  18.0          8   318.0       150.0    3436        11.0  1970
# 3      4  16.0          8   304.0       150.0    3433        12.0  1970
# 4      5  17.0          8   302.0       140.0    3449        10.5  1970
# ..   ...   ...        ...     ...         ...     ...         ...   ...
# 401  402  27.0          4   140.0        86.0    2790        15.6  1982
# 402  403  44.0          4    97.0        52.0    2130        24.6  1982
# 403  404  32.0          4   135.0        84.0    2295        11.6  1982
# 404  405  28.0          4   120.0        79.0    2625        18.6  1982
# 405  406  31.0          4   119.0        82.0    2720        19.4  1982
#
# [406 rows x 8 columns]

# %%
df.dropna()
# Out:
#       Id   MPG  Cylinders  Edispl  Horsepower  Weight  Accelerate  Year
# 0      1  18.0          8   307.0       130.0    3504        12.0  1970
# 1      2  15.0          8   350.0       165.0    3693        11.5  1970
# 2      3  18.0          8   318.0       150.0    3436        11.0  1970
# 3      4  16.0          8   304.0       150.0    3433        12.0  1970
# 4      5  17.0          8   302.0       140.0    3449        10.5  1970
# ..   ...   ...        ...     ...         ...     ...         ...   ...
# 401  402  27.0          4   140.0        86.0    2790        15.6  1982
# 402  403  44.0          4    97.0        52.0    2130        24.6  1982
# 403  404  32.0          4   135.0        84.0    2295        11.6  1982
# 404  405  28.0          4   120.0        79.0    2625        18.6  1982
# 405  406  31.0          4   119.0        82.0    2720        19.4  1982
#
# [392 rows x 8 columns]

# %%
df.isnull().sum().sum()
# Out:
# 14

# %%
df=df.dropna()

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
df
# Out:
#       Id   MPG  Cylinders  Edispl  Horsepower  Weight  Accelerate  Year
# 0      1  18.0          8   307.0       130.0    3504        12.0  1970
# 1      2  15.0          8   350.0       165.0    3693        11.5  1970
# 2      3  18.0          8   318.0       150.0    3436        11.0  1970
# 3      4  16.0          8   304.0       150.0    3433        12.0  1970
# 4      5  17.0          8   302.0       140.0    3449        10.5  1970
# ..   ...   ...        ...     ...         ...     ...         ...   ...
# 401  402  27.0          4   140.0        86.0    2790        15.6  1982
# 402  403  44.0          4    97.0        52.0    2130        24.6  1982
# 403  404  32.0          4   135.0        84.0    2295        11.6  1982
# 404  405  28.0          4   120.0        79.0    2625        18.6  1982
# 405  406  31.0          4   119.0        82.0    2720        19.4  1982
#
# [392 rows x 8 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 392 entries, 0 to 405
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Id          392 non-null    int64
#  1   MPG         392 non-null    float64
#  2   Cylinders   392 non-null    int64
#  3   Edispl      392 non-null    float64
#  4   Horsepower  392 non-null    float64
#  5   Weight      392 non-null    int64
#  6   Accelerate  392 non-null    float64
#  7   Year        392 non-null    int64
# dtypes: float64(4), int64(4)
# memory usage: 27.6 KB

# %%
df.head()
# Out:
#    Id   MPG  Cylinders  Edispl  Horsepower  Weight  Accelerate  Year
# 0   1  18.0          8   307.0       130.0    3504        12.0  1970
# 1   2  15.0          8   350.0       165.0    3693        11.5  1970
# 2   3  18.0          8   318.0       150.0    3436        11.0  1970
# 3   4  16.0          8   304.0       150.0    3433        12.0  1970
# 4   5  17.0          8   302.0       140.0    3449        10.5  1970

# %%
import seaborn as sns
sns.set()

# %%
df=df.astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 392 entries, 0 to 405
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Id          392 non-null    int32
#  1   MPG         392 non-null    int32
#  2   Cylinders   392 non-null    int32
#  3   Edispl      392 non-null    int32
#  4   Horsepower  392 non-null    int32
#  5   Weight      392 non-null    int32
#  6   Accelerate  392 non-null    int32
#  7   Year        392 non-null    int32
# dtypes: int32(8)
# memory usage: 25.3 KB

# %%
CorrMatrix = df.corr()
plt.subplots(figsize=(10,7.5))
sns.heatmap(CorrMatrix,annot=True,vmin=0.5, vmax=0.7)
plt.show()

# %%
plt.figure(figsize=(12,6))
plt.xlabel('Year', fontsize=15)
plt.ylabel('Horsepower  ', fontsize=15)
plt.title(" Fluctuation of Horsepower regarding Year",fontsize=18)

sns.distplot(df["Year"].values, label="Year");
sns.distplot(df["Horsepower"].values, label="Horsepower");
plt.legend()
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.jointplot(x = "MPG", y = "Accelerate",
              kind = "hex", data = df)
plt.show()

# %%
sns.catplot(x='Edispl', data=df, kind='count');

# %%
x=df['Cylinders']
y=df['Accelerate']
sns.regplot(x=x,y=y)
plt.show()

# %%
x=df['MPG']
y=df['Weight']
sns.regplot(x=x,y=y)
plt.show()

# %%
x=df['Year']
y=df['Edispl']
sns.regplot(x=x,y=y)
plt.show()

# %%
x=df['Accelerate']
x
# Out:
# 0      12
# 1      11
# 2      11
# 3      12
# 4      10
#        ..
# 401    15
# 402    24
# 403    11
# 404    18
# 405    19
# Name: Accelerate, Length: 392, dtype: int32

# %%
y=df['MPG']

# %%
y
# Out:
# 0      18
# 1      15
# 2      18
# 3      16
# 4      17
#        ..
# 401    27
# 402    44
# 403    32
# 404    28
# 405    31
# Name: MPG, Length: 392, dtype: int32

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, train_size = 0.7, 
                                                    test_size = 0.3)

# %%
x_train
# Out:
# 91     16
# 65     17
# 66     23
# 41     15
# 42     15
#        ..
# 78     13
# 295    15
# 112    13
# 211    17
# 213    13
# Name: Accelerate, Length: 274, dtype: int32

# %%
y_train
# Out:
# 91     27
# 65     25
# 66     23
# 41     16
# 42     17
#        ..
# 78     19
# 295    18
# 112    13
# 211    32
# 213    26
# Name: MPG, Length: 274, dtype: int32

# %%
import statsmodels.api as sm
x_train_sm = sm.add_constant(x_train)

# %%
regression = sm.OLS(y_train, x_train_sm).fit()

# %%
regression.params
# Out:
# const         7.824043
# Accelerate    1.014068
# dtype: float64

# %%
regression.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    MPG   R-squared:                       0.132
# Model:                            OLS   Adj. R-squared:                  0.129
# Method:                 Least Squares   F-statistic:                     41.33
# Date:                Mon, 21 Feb 2022   Prob (F-statistic):           5.75e-10
# Time:                        12:24:34   Log-Likelihood:                -927.35
# No. Observations:                 274   AIC:                             1859.
# Df Residuals:                     272   BIC:                             1866.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          7.8240      2.461      3.179      0.002       2.978      12.670
# ...

# %%
plt.scatter(x_train, y_train)
plt.show()

# %%
x_test
# Out:
# 5      10
# 214    15
# 119    18
# 319    16
# 56     14
#        ..
# 314    12
# 256    15
# 244    17
# 304    20
# 351    16
# Name: Accelerate, Length: 118, dtype: int32

# %%
y_test
# Out:
# 5      15
# 214    20
# 119    19
# 319    37
# 56     23
#        ..
# 314    26
# 256    19
# 244    30
# 304    25
# 351    39
# Name: MPG, Length: 118, dtype: int32

# %%
regression.rsquared
# Out:
# 0.13189795688167893

# %%
x_test_sm = sm.add_constant(X_test)


y_test_pred = regression.predict(x_test_sm)


y_test_pred
# Out:
# 69     70.696260
# 300    76.780668
# 220    71.710328
# 134    49.400831
# 7      52.443035
#          ...
# 203    76.780668
# 237    68.668124
# 29     61.569648
# 161    63.597784
# 266    63.597784
# Length: 91, dtype: float64

# %%
plt.scatter(x_test, y_test)

plt.show()
